# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Rakesh\Desktop\Third phase\Automobile_insurance_fraud.csv")
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
data.shape
# Out:
# (1000, 40)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
data.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
data=data.drop(columns=['_c39'])
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
data=data.drop(columns=['policy_number'])
data.head()
# Out:
#    months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                 328   48       17-10-2014           OH    250/500
# 1                 228   42       27-06-2006           IN    250/500
# 2                 134   29       06-09-2000           OH    100/300
# 3                 256   41       25-05-1990           IL    250/500
# 4                 228   44       06-06-2014           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0               1000                1406.91               0       466132
# 1               2000                1197.22         5000000       468176
# 2               2000                1413.14         5000000       430632
# 3               2000                1415.74         6000000       608117
# 4               1000                1583.91         6000000       610706
#
#   insured_sex  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
data=data.drop(columns=['policy_bind_date'])
data.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 4                 228   44           IL   500/1000               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                1406.91               0       466132        MALE
# 1                1197.22         5000000       468176        MALE
# 2                1413.14         5000000       430632      FEMALE
# 3                1415.74         6000000       608117      FEMALE
# 4                1583.91         6000000       610706        MALE
#
#   insured_education_level  ... witnesses police_report_available  \
# 0                      MD  ...         2                     YES
# ...

# %%
data=data.drop(columns=['policy_csl'])
data.head()
# Out:
#    months_as_customer  age policy_state  policy_deductable  \
# 0                 328   48           OH               1000
# 1                 228   42           IN               2000
# 2                 134   29           OH               2000
# 3                 256   41           IL               2000
# 4                 228   44           IL               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                1406.91               0       466132        MALE
# 1                1197.22         5000000       468176        MALE
# 2                1413.14         5000000       430632      FEMALE
# 3                1415.74         6000000       608117      FEMALE
# 4                1583.91         6000000       610706        MALE
#
#   insured_education_level insured_occupation  ... witnesses  \
# 0                      MD       craft-repair  ...         2
# 1                      MD  machine-op-inspct  ...         0
# ...

# %%
data=data.drop(columns=['incident_date'])
data.head()
# Out:
#    months_as_customer  age policy_state  policy_deductable  \
# 0                 328   48           OH               1000
# 1                 228   42           IN               2000
# 2                 134   29           OH               2000
# 3                 256   41           IL               2000
# 4                 228   44           IL               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                1406.91               0       466132        MALE
# 1                1197.22         5000000       468176        MALE
# 2                1413.14         5000000       430632      FEMALE
# 3                1415.74         6000000       608117      FEMALE
# 4                1583.91         6000000       610706        MALE
#
#   insured_education_level insured_occupation  ... witnesses  \
# 0                      MD       craft-repair  ...         2
# 1                      MD  machine-op-inspct  ...         0
# ...

# %%
data['incident_city']
# Out:
# 0        Columbus
# 1       Riverwood
# 2        Columbus
# 3       Arlington
# 4       Arlington
#           ...
# 995    Northbrook
# 996     Northbend
# 997     Arlington
# 998     Arlington
# 999      Columbus
# Name: incident_city, Length: 1000, dtype: object

# %%
data['incident_city'].nunique()
# Out:
# 7

# %%
lab_enc=LabelEncoder()

# %%
data1=lab_enc.fit_transform(data['policy_state'])
data['policy_state']=data1
pd.Series(data1)
# Out:
# 0      2
# 1      1
# 2      2
# 3      0
# 4      0
#       ..
# 995    2
# 996    0
# 997    2
# 998    0
# 999    2
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['insured_sex'])
data['insured_sex']=data1
pd.Series(data1)
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    1
# 999    0
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['insured_education_level'])
data['insured_education_level']=data1
pd.Series(data1)
# Out:
# 0      4
# 1      4
# 2      6
# 3      6
# 4      0
#       ..
# 995    5
# 996    6
# 997    5
# 998    0
# 999    0
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['insured_occupation'])
data['insured_occupation']=data1
pd.Series(data1)
# Out:
# 0       2
# 1       6
# 2      11
# 3       1
# 4      11
#        ..
# 995     2
# 996     9
# 997     1
# 998     5
# 999    11
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['insured_hobbies'])
data['insured_hobbies']=data1
pd.Series(data1)
# Out:
# 0      17
# 1      15
# 2       2
# 3       2
# 4       2
#        ..
# 995    13
# 996    17
# 997     3
# 998     0
# 999    11
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['insured_relationship'])
data['insured_relationship']=data1
pd.Series(data1)
# Out:
# 0      0
# 1      2
# 2      3
# 3      4
# 4      4
#       ..
# 995    4
# 996    5
# 997    2
# 998    5
# 999    0
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['collision_type'])
data['collision_type']=data1
pd.Series(data1)
# Out:
# 0      3
# 1      0
# 2      2
# 3      1
# 4      0
#       ..
# 995    1
# 996    2
# 997    3
# 998    2
# 999    0
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['incident_severity'])
data['incident_severity']=data1
pd.Series(data1)
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    0
# 999    1
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['authorities_contacted'])
data['authorities_contacted']=data1
pd.Series(data1)
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      2
#       ..
# 995    1
# 996    1
# 997    4
# 998    3
# 999    4
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['incident_state'])
data['incident_state']=data1
pd.Series(data1)
# Out:
# 0      4
# 1      5
# 2      1
# 3      2
# 4      1
#       ..
# 995    0
# 996    4
# 997    0
# 998    1
# 999    6
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['incident_city'])
data['incident_city']=data1
pd.Series(data1)
# Out:
# 0      1
# 1      5
# 2      1
# 3      0
# 4      0
#       ..
# 995    4
# 996    3
# 997    0
# 998    0
# 999    1
# Length: 1000, dtype: int32

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
data['fraud_reported']
# Out:
# 0      Y
# 1      Y
# 2      N
# 3      Y
# 4      N
#       ..
# 995    N
# 996    N
# 997    N
# 998    N
# 999    N
# Name: fraud_reported, Length: 1000, dtype: object

# %%
data['fraud_reported'].nunique()
# Out:
# 2

# %%
data=data.drop(columns=['incident_location'])
data.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# 0                1406.91               0       466132            1
# 1                1197.22         5000000       468176            1
# 2                1413.14         5000000       430632            0
# 3                1415.74         6000000       608117            0
# 4                1583.91         6000000       610706            1
#
#    insured_education_level  insured_occupation  ...  witnesses  \
# 0                        4                   2  ...          2
# 1                        4                   6  ...          0
# ...

# %%
data1=lab_enc.fit_transform(data['property_damage'])
data['property_damage']=data1
pd.Series(data1)
# Out:
# 0      2
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    2
# 996    2
# 997    0
# 998    0
# 999    0
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['police_report_available'])
data['police_report_available']=data1
pd.Series(data1)
# Out:
# 0      2
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 995    0
# 996    0
# 997    2
# 998    2
# 999    0
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['auto_make'])
data['auto_make']=data1
pd.Series(data1)
# Out:
# 0      10
# 1       8
# 2       4
# 3       3
# 4       0
#        ..
# 995     6
# 996    13
# 997    11
# 998     1
# 999     8
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['auto_model'])
data['auto_model']=data1
pd.Series(data1)
# Out:
# 0       1
# 1      12
# 2      30
# 3      34
# 4      31
#        ..
# 995     6
# 996    28
# 997    19
# 998     5
# 999    12
# Length: 1000, dtype: int32

# %%
data1=lab_enc.fit_transform(data['fraud_reported'])
data['fraud_reported']=data1
pd.Series(data1)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Length: 1000, dtype: int32

# %%
data.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# 0                1406.91               0       466132            1
# 1                1197.22         5000000       468176            1
# 2                1413.14         5000000       430632            0
# 3                1415.74         6000000       608117            0
# 4                1583.91         6000000       610706            1
#
#    insured_education_level  insured_occupation  ...  witnesses  \
# 0                        4                   2  ...          2
# 1                        4                   6  ...          0
# ...

# %%
y = data['fraud_reported']
x=data.drop(columns=['fraud_reported'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=355)

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print('\n==========================Train Result=====================')
        print(f'Accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%')
    elif train==False:
        pred=clf.predict(x_test)
        print('\n==========================Test Result=====================')
        print(f'Accuracy score:{accuracy_score(y_test,pred)*100:.2f}%')
        
        print('\n\n Test classifiaction report\n',classification_report(y_test,pred,digits=2))

# %%
random_clf=RandomForestClassifier()

random_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
metric_score(random_clf,x_train,x_test,y_train,y_test,train=True)
metric_score(random_clf,x_train,x_test,y_train,y_test,train=False)
# Out:
# ==========================Train Result=====================
# Accuracy score:100.00%
#
# ==========================Test Result=====================
# Accuracy score:74.40%
#
#
#  Test classifiaction report
#                precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       182
#            1       0.56      0.29      0.38        68
#
#     accuracy                           0.74       250
#    macro avg       0.67      0.60      0.61       250
# weighted avg       0.72      0.74      0.71       250
